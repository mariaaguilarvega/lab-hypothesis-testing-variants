# %% [markdown]
# # Challenge 1 - T-test
#
# In statistics, t-test is used to test if two data samples have a significant difference between their means. There are two types of t-test:
#
# * **Student's t-test** (a.k.a. independent or uncorrelated t-test). This type of t-test is to compare the samples of **two independent populations** (e.g. test scores of students in two different classes). `scipy` provides the [`ttest_ind`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_ind.html) method to conduct student's t-test.
#
# * **Paired t-test** (a.k.a. dependent or correlated t-test). This type of t-test is to compare the samples of **the same population** (e.g. scores of different tests of students in the same class). `scipy` provides the [`ttest_re`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_rel.html) method to conduct paired t-test.
#
# Both types of t-tests return a number which is called the **p-value**. If p-value is below 0.05, we can confidently declare the null-hypothesis is rejected and the difference is significant. If p-value is between 0.05 and 0.1, we may also declare the null-hypothesis is rejected but we are not highly confident. If p-value is above 0.1 we do not reject the null-hypothesis.
#
# Read more about the t-test in [this article](http://b.link/test50) and [this Quora](http://b.link/unpaired97). Make sure you understand when to use which type of t-test.

# %%
# Import libraries
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import ttest_ind, ttest_rel

# %% [markdown]
# #### Import dataset
#
# In this challenge we will work on the Pokemon dataset. The goal is to test whether different groups of pokemon (e.g. Legendary vs Normal, Generation 1 vs 2, single-type vs dual-type) have different stats (e.g. HP, Attack, Defense, etc.).

# %%
# Your code here:
pokemon_df = pd.read_csv('Pokemon.csv')
display(pokemon_df.head())
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# #### First we want to define a function with which we can test the means of a feature set of two samples.
#
# In the next cell you'll see the annotations of the Python function that explains what this function does and its arguments and returned value. This type of annotation is called **docstring** which is a convention used among Python developers. The docstring convention allows developers to write consistent tech documentations for their codes so that others can read. It also allows some websites to automatically parse the docstrings and display user-friendly documentations.
#
# Follow the specifications of the docstring and complete the function.

# %%
def t_test_features(s1, s2, features=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']):
    """Test means of a feature set of two samples
    
    Args:
        s1 (dataframe): sample 1
        s2 (dataframe): sample 2
        features (list): an array of features to test
    
    Returns:
        dict: a dictionary of t-test scores for each feature where the feature name is the key and the p-value is the value
    """
    results = {}

    for feature in features:
        # Perform t-test
        t_stat, p_value = ttest_ind(s1[feature], s2[feature], equal_var=False)
        # Store the feature's p-value
        results[feature] = p_value
    
    
    return results

# %% [markdown]
# #### Using the `t_test_features` function, conduct t-test for Lengendary vs non-Legendary pokemons.
#
# *Hint: your output should look like below:*
#
# ```
# {'HP': 1.0026911708035284e-13,
#  'Attack': 2.520372449236646e-16,
#  'Defense': 4.8269984949193316e-11,
#  'Sp. Atk': 1.5514614112239812e-21,
#  'Sp. Def': 2.2949327864052826e-15,
#  'Speed': 1.049016311882451e-18,
#  'Total': 9.357954335957446e-47}
#  ```

# %%
# Your code here
lengendary_pokemons = pokemon_df[pokemon_df['Legendary'] == True]
normal_pokemons = pokemon_df[pokemon_df['Legendary'] == False]
display(lengendary_pokemons.sample(10))
display(normal_pokemons.sample(10))

t_test_features(lengendary_pokemons,normal_pokemons)
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 707  644                 Zekrom    Dragon  Electric    680  100     150
# 710  646                 Kyurem    Dragon       Ice    660  125     130
# 162  150                 Mewtwo   Psychic       NaN    680  106     110
# 538  481                Mesprit   Psychic       NaN    580   80     105
# 429  386     DeoxysAttack Forme   Psychic       NaN    600   50     180
# 262  243                 Raikou  Electric       NaN    580   90      85
# 537  480                   Uxie   Psychic       NaN    580   75      75
# 709  645  LandorusTherian Forme    Ground    Flying    600   89     145
# 797  720    HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 420  381      LatiosMega Latios    Dragon   Psychic    700   80     130
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 707      120      120      100     90           5       True
# ...

# %% [markdown]
# #### From the test results above, what conclusion can you make? Do Legendary and non-Legendary pokemons have significantly different stats on each feature?

# %%
# Your comment here

#all p-values are lower than 0.05 so we can say there are significant difference on features between Legendary and non-Legendary pokemons

# %% [markdown]
# #### Next, conduct t-test for Generation 1 and Generation 2 pokemons.

# %%
# Your code here
gen1_pokemons = pokemon_df[pokemon_df['Generation'] == 1]
gen2_pokemons = pokemon_df[pokemon_df['Generation'] == 2]

display(gen1_pokemons.sample(5))
display(gen2_pokemons.sample(5))

t_test_features(gen1_pokemons,gen2_pokemons)
# Out:
#        #                       Name    Type 1  Type 2  Total  HP  Attack  \
# 114  106                  Hitmonlee  Fighting     NaN    455  50     120
# 154  142  AerodactylMega Aerodactyl      Rock  Flying    615  80     135
# 15    12                 Butterfree       Bug  Flying    395  60      45
# 144  133                      Eevee    Normal     NaN    325  55      55
# 21    17                  Pidgeotto    Normal  Flying    349  63      60
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 114       53       35      110     87           1      False
# 154       85       70       95    150           1      False
# 15        50       90       80     70           1      False
# 144       50       45       65     55           1      False
# 21        55       50       50     71           1      False
#        #      Name    Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 255  236   Tyrogue  Fighting      NaN    210  35      35       35       35
# ...

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
#For all features except Speed, the p-values indicate that the differences in means are not statistically significant. 
#This means we cannot confidently conclude that gen1 and gen2 pokemons are different in these features. However we can say that
#Speed between gen1 and gen2 pokemons is statistically significant.

# %% [markdown]
# #### Compare pokemons who have single type vs those having two types.

# %%
# Your code here

pokemon_df['Number of Types'] = pokemon_df['Type 2'].apply(lambda x: 1 if pd.isna(x) else 2)

onetype_pokemons = pokemon_df[pokemon_df['Number of Types'] == 1]
twotype_pokemons = pokemon_df[pokemon_df['Number of Types'] == 2]

display(onetype_pokemons.sample(5))
display(twotype_pokemons.sample(5))


t_test_features(onetype_pokemons,twotype_pokemons)
# Out:
#        #               Name  Type 1 Type 2  Total   HP  Attack  Defense  \
# 250  231             Phanpy  Ground    NaN    330   90      60       60
# 289  266            Silcoon     Bug    NaN    205   50      35       55
# 395  361            Snorunt     Ice    NaN    300   50      50       50
# 563  504             Patrat  Normal    NaN    255   45      55       39
# 550  492  ShayminLand Forme   Grass    NaN    600  100     100      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Number of Types
# 250       40       40     40           2      False                1
# 289       25       25     15           3      False                1
# 395       50       50     50           3      False                1
# 563       35       39     42           5      False                1
# 550      100      100    100           4       True                1
#        #                     Name   Type 1  Type 2  Total  HP  Attack  \
# ...

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here

#both pokemon types differ significantly in most stats (Attack, Defense, Sp. Atk, Sp. Def, Speed, and Total). Even in speed there is no lot of
#difference for speed
# However, there is no strong evidence of a difference in their HP stat.

# %% [markdown]
# #### Now, we want to compare whether there are significant differences of `Attack` vs `Defense`  and  `Sp. Atk` vs `Sp. Def` of all pokemons. Please write your code below.
#
# *Hint: are you comparing different populations or the same population?*

# %%
# Your code here
  
display(ttest_rel(pokemon_df['Attack'], pokemon_df['Defense']))
display(ttest_rel(pokemon_df['Sp. Atk'], pokemon_df['Sp. Def']))
# Out:
# TtestResult(statistic=4.325566393330478, pvalue=1.7140303479358558e-05, df=799)
# TtestResult(statistic=0.853986188453353, pvalue=0.3933685997548122, df=799)

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
#pokemon stats differ significantly in Attack vs Defense.
#However  there is no significant difference between Sp. Atk and Sp. Def.
